# %% [markdown]
# ![datframe.png](data:image/png;base64,...)

# %% [markdown]
# ![Picture2.png](data:image/png;base64,...)

# %%
#Creating an Empty Dataframe

import pandas as pd
#Empty Dataframe
df=pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#Creating Dataframe from List of Dicitonaries
import pandas as pd
d=[{'Name':'Geetu','Roll':1},{'Name':'Aaliyah','Roll':2},{'Name':'Ananya','Roll':3}]
#List of dictionaries
df=pd.DataFrame(d,index=['A','B','C'])
df
# Out:
#       Name  Roll
# A    Geetu     1
# B  Aaliyah     2
# C   Ananya     3

# %%
#Another example
d=[{'Name':'Geetu', 'Subject':'Python'} , {'Name':'Neha','Subject':'Math'}, {'Name':'Philips','Subject':'English'}]
df=pd.DataFrame(d,columns=['Name','Subject','Time'],index=['Mon','Tue','Wed'])
# print(df)

#Adding a new column
df['Time']='6:00'
print(df)
# Out:
#         Name  Subject  Time
# Mon    Geetu   Python  6:00
# Tue     Neha     Math  6:00
# Wed  Philips  English  6:00

# %%
#Creating Dataframe from List of List
import pandas as pd
L=[['Geetu','Python'],['Neha','Math'],['Philips','English']]
df=pd.DataFrame(L,columns=['Name','Subject'],index=['Mon','Tue','Wed'])
df
# Out:
#         Name  Subject
# Mon    Geetu   Python
# Tue     Neha     Math
# Wed  Philips  English

# %%
#Creating Dataframe from Dictionary of Lists { key:[], key:[]        }

d2={'Rollno':[23,34,45,46],'Name':['Geetu','Joy','Philips','Katie'],'Subject':['Python','English','French','Math']}

df4=pd.DataFrame(d2,index=['Monday','Tuesday','Wednesday','Thursday'])

df4
# Out:
#            Rollno     Name  Subject
# Monday         23    Geetu   Python
# Tuesday        34      Joy  English
# Wednesday      45  Philips   French
# Thursday       46    Katie     Math

# %% [markdown]
# # **DATFRAME ATTRIBUTES**

# %%
#Return an int representing the number of elements in given dataframe.
df.size
# Out:
# 6

# %%
#Return a tuple representing the dimensions of the DataFrame.
df.shape
# Out:
# (3, 2)

# %%
#Return a list representing the axes of the DataFrame.
df.axes
# Out:
# [Index(['Mon', 'Tue', 'Wed'], dtype='object'),
#  Index(['Name', 'Subject'], dtype='object')]

# %%
#Return an int representing the number of axes / array dimensions
df.ndim
# Out:
# 2

# %%
#The column labels of the DataFrame
df.columns
# Out:
# Index(['Name', 'Subject'], dtype='object')

# %%
#Return a Numpy representation of the DataFrame.
df.values
# Out:
# array([['Geetu', 'Python'],
#        ['Neha', 'Math'],
#        ['Philips', 'English']], dtype=object)

# %% [markdown]
# **Adding a new column/ row**

# %%
#Adding column to the existing dataframe
df["Grade"] = ["C","B","A"]
df

# %%
# Using loc() to add row or column/access/display row or column
# IMPORTANT: A column can also be added using loc() method. New row can be added to a dataframe using loc() method.
df.loc[:,"Grade2"] = ["C","B","A"]
df

# %%
#Adding a row

df.loc[3]=["Nancy","English","B","A"]
df

# %% [markdown]
# **DELETING ROW/COLUMN**

# %%
df.drop("Grade2", axis=1)
df

# %%
df.drop(3, axis=0)
df

# %%
df.drop([1,2] , axis=0)
df

# %% [markdown]
# **RENAMING ROW/ COLUMN**

# %%
df2=df.rename({'Rollno':'Roll', 'Total':'Tot', 'Percentage':'Per'}, axis= 'columns')
df2=df.rename(columns={'Rollno':'Roll', 'Total':'Tot', 'Percentage':'Per'})

# %% [markdown]
# **IMPORTING DATA FROM A CSV / EXCEL INTO DATAFRAME**

# %%
#Importing Data into Datframe directly from csv/Excel files

import pandas as pd
df=pd.read_csv("Chicago_Public_School.csv")
df.tail(20)
#Choosing to keep only few columns
data=df.loc[:,['School ID','NAME_OF_SCHOOL','Elementary, Middle, or High School','City','SAFETY_SCORE','Environment Score']]
data.head()
# data[data['Elementary, Middle, or High School']=='ES']
# Out:
#    School ID                                     NAME_OF_SCHOOL  \
# 0     610038                  Abraham Lincoln Elementary School
# 1     610281  Adam Clayton Powell Paideia Community Academy ...
# 2     610185                Adlai E Stevenson Elementary School
# 3     609993                    Agustin Lara Elementary Academy
# 4     610513                      Air Force Academy High School
#
#   Elementary, Middle, or High School     City  SAFETY_SCORE  Environment Score
# 0                                 ES  Chicago          99.0               74.0
# 1                                 ES  Chicago          54.0               74.0
# 2                                 ES  Chicago          61.0               50.0
# 3                                 ES  Chicago          56.0               45.0
# 4                                 HS  Chicago          49.0               60.0

# %% [markdown]
# # ACCESSING DATA FROM A DATFRAME
# **SELECTING A PARTICULAR COLUMN**

# %%
data.NAME_OF_SCHOOL
# Out:
# 0                      Abraham Lincoln Elementary School
# 1      Adam Clayton Powell Paideia Community Academy ...
# 2                    Adlai E Stevenson Elementary School
# 3                        Agustin Lara Elementary Academy
# 4                          Air Force Academy High School
#                              ...
# 561                  William T Sherman Elementary School
# 562                   William W Carter Elementary School
# 563                  Wolfgang A Mozart Elementary School
# 564                 Woodlawn Community Elementary School
# 565                   World Language Academy High School
# Name: NAME_OF_SCHOOL, Length: 566, dtype: object

# %%
data['NAME_OF_SCHOOL']
# Out:
# 0                      Abraham Lincoln Elementary School
# 1      Adam Clayton Powell Paideia Community Academy ...
# 2                    Adlai E Stevenson Elementary School
# 3                        Agustin Lara Elementary Academy
# 4                          Air Force Academy High School
#                              ...
# 561                  William T Sherman Elementary School
# 562                   William W Carter Elementary School
# 563                  Wolfgang A Mozart Elementary School
# 564                 Woodlawn Community Elementary School
# 565                   World Language Academy High School
# Name: NAME_OF_SCHOOL, Length: 566, dtype: object

# %%
df[['NAME_OF_SCHOOL','City']]
# Out:
#                                         NAME_OF_SCHOOL     City
# 0                    Abraham Lincoln Elementary School  Chicago
# 1    Adam Clayton Powell Paideia Community Academy ...  Chicago
# 2                  Adlai E Stevenson Elementary School  Chicago
# 3                      Agustin Lara Elementary Academy  Chicago
# 4                        Air Force Academy High School  Chicago
# ..                                                 ...      ...
# 561                William T Sherman Elementary School  Chicago
# 562                 William W Carter Elementary School  Chicago
# 563                Wolfgang A Mozart Elementary School  Chicago
# 564               Woodlawn Community Elementary School  Chicago
# 565                 World Language Academy High School  Chicago
#
# [566 rows x 2 columns]

# %% [markdown]
# # ACCESSING DATAFRAMES
#
# The data present in the DataFrames can be accessed using indexing and slicing.
# INDEXING
#
# **Indexing in DataFrames is of two types:**
#
# Label based Indexing
#
# Boolean Indexing.

# %% [markdown]
# ![Picture1.png](data:image/png;base64,...)

# %%
#The loc() method is used for label based indexing. It accepts row/column labels as parameters.
#Dataframe.loc[start_row:end_row,start_col:end_col]

#To display the row with row label 2, the command is:
df.loc[2,:]

#where the symbol : indicates all columns.
# Out:
# School ID                                                          610185
# NAME_OF_SCHOOL                        Adlai E Stevenson Elementary School
# Elementary, Middle, or High School                                     ES
# Street Address                                        8010 S Kostner Ave
# City                                                              Chicago
#                                                      ...
# COMMUNITY_AREA_NUMBER                                                  70
# COMMUNITY_AREA_NAME                                               ASHBURN
# Ward                                                                   13
# Police District                                                         8
# Location                                      (41.74711093, -87.73170248)
# Name: 2, Length: 78, dtype: object

# %%
df.loc[2]
# Out:
# School ID                                                          610185
# NAME_OF_SCHOOL                        Adlai E Stevenson Elementary School
# Elementary, Middle, or High School                                     ES
# Street Address                                        8010 S Kostner Ave
# City                                                              Chicago
#                                                      ...
# COMMUNITY_AREA_NUMBER                                                  70
# COMMUNITY_AREA_NAME                                               ASHBURN
# Ward                                                                   13
# Police District                                                         8
# Location                                      (41.74711093, -87.73170248)
# Name: 2, Length: 78, dtype: object

# %%
# To access columns: use:
# DF.loc[:,start column:end column] Make sure not to miss the COLON BEFORE COMMA.
df.loc[:,"SAFETY_SCORE"]
# Out:
# 0      99.0
# 1      54.0
# 2      61.0
# 3      56.0
# 4      49.0
#        ...
# 561    32.0
# 562    13.0
# 563    41.0
# 564    70.0
# 565    51.0
# Name: SAFETY_SCORE, Length: 566, dtype: float64

# %% [markdown]
# **We can easily retrieve a slice of rows and columns using loc() and iloc() methods.**
#
# The loc[] method is used to retrieve the group of rows and columns by labels or a boolean array present in the DataFrame. It takes only index labels, and if it exists in the called DataFrame, it returns the rows, columns, or DataFrame.

# %% [markdown]
# **The .iloc[] method is used retrieve the group of rows and columns at particular positions in the index so it only takes integers. It is used when the index label of the DataFrame **is other than numeric series of 0,1,2,	,n, or in the case when the user
# does not know the index label

# %% [markdown]
# ![pandas-different-between-loc-vs-iloc-2.webp](data:image/webp;base64,...)

# %%
df.iloc[::100,::2]

#every 100th record and every alternate column
# Out:
#      School ID                                  NAME_OF_SCHOOL  \
# 0       610038               Abraham Lincoln Elementary School
# 100     609870              Daniel J Corkery Elementary School
# 200     609920  Gerald Delgado Kanoon Elementary Magnet School
# 300     609937                  John W Garvy Elementary School
# 400     610323   New Millennium High School of Health at Bowen
# 500     610178             Theophilus Schmid Elementary School
#
#     Elementary, Middle, or High School         Street Address     City State  \
# 0                                   ES       615 W Kemper Pl   Chicago    IL
# 100                                 ES    2510 S Kildare Ave   Chicago    IL
# 200                                 ES     2233 S Kedzie Ave   Chicago    IL
# 300                                 ES   5225 N Oak Park Ave   Chicago    IL
# 400                                 HS        2710 E 89th St   Chicago    IL
# 500                                 ES  9755 S Greenwood Ave   Chicago    IL
#
#      ZIP Code    Phone Number  \
# 0       60614  (773) 534-5720
# 100     60623  (773) 534-1650
# 200     60623  (773) 534-1736
# 300     60656  (773) 534-1185
# 400     60617  (773) 535-7650
# 500     60628  (773) 535-6235
#
#                                                  Link   \
# 0    http://schoolreports.cps.edu/SchoolProgressRep...
# 100  http://schoolreports.cps.edu/SchoolProgressRep...
# 200  http://schoolreports.cps.edu/SchoolProgressRep...
# 300  http://schoolreports.cps.edu/SchoolProgressRep...
# 400  http://schoolreports.cps.edu/SchoolProgressRep...
# 500  http://schoolreports.cps.edu/SchoolProgressRep...
#
#                               Network Manager  ... Freshman on Track Rate %  \
# 0                Fullerton Elementary Network  ...                      NDA
# 100  Pilsen-Little Village Elementary Network  ...                      NDA
# 200  Pilsen-Little Village Elementary Network  ...                      NDA
# 300                 O'Hare Elementary Network  ...                      NDA
# 400            South Side High School Network  ...                     62.1
# 500           Lake Calumet Elementary Network  ...                      NDA
#
#     X_COORDINATE Y_COORDINATE   Latitude  Longitude COMMUNITY_AREA_NUMBER  \
# 0    1171699.458  1915829.428  41.924497 -87.644522                     7
# 100  1148304.879  1886901.414  41.845599 -87.731229                    30
# 200  1155417.273  1888838.931  41.850776 -87.705075                    30
# 300  1130304.414  1934430.694  41.976353 -87.796198                    10
# 400  1195939.937  1846527.528  41.733761 -87.557753                    46
# 500  1185308.063  1840332.575  41.717018 -87.596896                    50
#
#     COMMUNITY_AREA_NAME  Ward Police District                     Location
# 0          LINCOLN PARK    43              18  (41.92449696, -87.64452163)
# 100      SOUTH LAWNDALE    22              10  (41.84559878, -87.73122946)
# 200      SOUTH LAWNDALE    24              10  (41.85077575, -87.70507547)
# 300        NORWOOD PARK    41              16  (41.97635262, -87.79619832)
# 400       SOUTH CHICAGO     7               4  (41.73376107, -87.55775263)
# 500             PULLMAN     8               5  (41.71701772, -87.59689622)
#
# [6 rows x 78 columns]

# %% [markdown]
# **BOOLEAN INDEXING IN DATAFRAMES**
# Instead of selecting data on the basis of row or column labels we can also select the data based on their values present in the dataframe.

# %% [markdown]
# ![Picture2.png](data:image/png;base64,...)

# %%
df['SAFETY_SCORE'].head()
# Out:
# 0    99.0
# 1    54.0
# 2    61.0
# 3    56.0
# 4    49.0
# Name: SAFETY_SCORE, dtype: float64

# %%
# To check how many students have got Total>=400 we will give the following command:

df["SAFETY_SCORE"]>=90
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 561    False
# 562    False
# 563    False
# 564    False
# 565    False
# Name: SAFETY_SCORE, Length: 566, dtype: bool

# %%
#To extract data of the aboce condiiton which is true
df[df["SAFETY_SCORE"]>=90 ]
# Out:
#      School ID                                     NAME_OF_SCHOOL  \
# 0       610038                  Abraham Lincoln Elementary School
# 10      609799            Alexander Graham Bell Elementary School
# 27      610084       Annie Keller Elementary Gifted Magnet School
# 39      609820                Augustus H Burley Elementary School
# 118     610132        Edgar Allan Poe Elementary Classical School
# 119     609901                        Edgebrook Elementary School
# 120     610523                      Edison Park Elementary School
# 141     610073                   Ellen Mitchell Elementary School
# 213     609974            Hawthorne Elementary Scholastic Academy
# 244     610066         James E McDade Elementary Classical School
# 245     609803                   James G Blaine Elementary School
# 286     609782                   John J Audubon Elementary School
# 326     610033                LaSalle Elementary Language Academy
# 366     610355   Mary E Courtenay Elementary Language Arts Center
# 408     609749          Northside College Preparatory High School
# 410     609744              Northside Learning Center High School
# 412     610099                     Norwood Park Elementary School
# 417     610105                      Oriole Park Elementary School
# 446     609769             Ray Graham Training Center High School
# 474     610155                        Sauganash Elementary School
# 488     609880        Stephen Decatur Classical Elementary School
# 494     610249                           Talman Elementary School
# 501     609794  Thomas A Edison Regional Gifted Center Element...
# 518     609680      Walter Payton College Preparatory High School
# 531     609755                 Whitney M Young Magnet High School
# 532     610230                         Wildwood Elementary School
# 546     610136               William H Prescott Elementary School
# 553     609678      William Jones College Preparatory High School
#
#     Elementary, Middle, or High School          Street Address     City State  \
# 0                                   ES        615 W Kemper Pl   Chicago    IL
# 10                                  ES      3730 N Oakley Ave   Chicago    IL
# 27                                  ES        3020 W 108th St   Chicago    IL
# 39                                  ES       1630 W Barry Ave   Chicago    IL
# 118                                 ES    10538 S Langley Ave   Chicago    IL
# 119                                 ES    6525 N Hiawatha Ave   Chicago    IL
# 120                                 ES      6220 N Olcott Ave   Chicago    IL
# 141                                 ES         2233 W Ohio St   Chicago    IL
# 213                                 ES     3319 N Clifton Ave   Chicago    IL
# 244                                 ES     8801 S Indiana Ave   Chicago    IL
# 245                                 ES        1420 W Grace St   Chicago    IL
# 286                                 ES       3500 N Hoyne Ave   Chicago    IL
# 326                                 ES      1734 N Orleans St   Chicago    IL
# 366                                 ES     1726 W Berteau Ave   Chicago    IL
# 408                                 HS      5501 N Kedzie Ave   Chicago    IL
# 410                                 HS   3730 W Bryn Mawr Ave   Chicago    IL
# 412                                 ES        5900 N Nina Ave   Chicago    IL
# 417                                 ES       5424 N Oketo Ave   Chicago    IL
# 446                                 HS      2347 S Wabash Ave   Chicago    IL
# 474                                 ES  6040 N Kilpatrick Ave   Chicago    IL
# 488                                 ES  7030 N Sacramento Ave   Chicago    IL
# 494                                 ES      5450 S Talman Ave   Chicago    IL
# 501                                 ES      4929 N Sawyer Ave   Chicago    IL
# 518                                 HS        1034 N Wells St   Chicago    IL
# 531                                 HS        211 S Laflin St   Chicago    IL
# 532                                 ES    6950 N Hiawatha Ave   Chicago    IL
# 546                                 ES  1632 W Wrightwood Ave   Chicago    IL
# 553                                 HS         606 S State St   Chicago    IL
#
#      ZIP Code    Phone Number  \
# 0       60614  (773) 534-5720
# 10      60618  (773) 534-5150
# 27      60655  (773) 535-2636
# 39      60657  (773) 534-5475
# 118     60628  (773) 535-5525
# 119     60646  (773) 534-1194
# 120     60631  (773) 534-0960
# 141     60612  (773) 534-7655
# 213     60657  (773) 534-5550
# 244     60619  (773) 535-3669
# 245     60613  (773) 534-5750
# 286     60618  (773) 534-5470
# 326     60614  (773) 534-8470
# 366     60613  (773) 534-5790
# 408     60625  (773) 534-3954
# 410     60659  (773) 534-5180
# 412     60631  (773) 534-1198
# 417     60656  (773) 534-1201
# 446     60616  (773) 534-9257
# 474     60646  (773) 534-3470
# 488     60645  (773) 534-2201
# 494     60632  (773) 535-7850
# 501     60625  (773) 534-0540
# 518     60610  (773) 534-0034
# 531     60607  (773) 534-7500
# 532     60646  (773) 534-1188
# 546     60614  (773) 534-5505
# 553     60605  (773) 534-8600
#
#                                                  Link   \
# 0    http://schoolreports.cps.edu/SchoolProgressRep...
# 10   http://schoolreports.cps.edu/SchoolProgressRep...
# 27   http://schoolreports.cps.edu/SchoolProgressRep...
# 39   http://schoolreports.cps.edu/SchoolProgressRep...
# 118  http://schoolreports.cps.edu/SchoolProgressRep...
# 119  http://schoolreports.cps.edu/SchoolProgressRep...
# 120  http://schoolreports.cps.edu/SchoolProgressRep...
# 141  http://schoolreports.cps.edu/SchoolProgressRep...
# 213  http://schoolreports.cps.edu/SchoolProgressRep...
# 244  http://schoolreports.cps.edu/SchoolProgressRep...
# 245  http://schoolreports.cps.edu/SchoolProgressRep...
# 286  http://schoolreports.cps.edu/SchoolProgressRep...
# 326  http://schoolreports.cps.edu/SchoolProgressRep...
# 366  http://schoolreports.cps.edu/SchoolProgressRep...
# 408  http://schoolreports.cps.edu/SchoolProgressRep...
# 410  http://schoolreports.cps.edu/SchoolProgressRep...
# 412  http://schoolreports.cps.edu/SchoolProgressRep...
# 417  http://schoolreports.cps.edu/SchoolProgressRep...
# 446  http://schoolreports.cps.edu/SchoolProgressRep...
# 474  http://schoolreports.cps.edu/SchoolProgressRep...
# 488  http://schoolreports.cps.edu/SchoolProgressRep...
# 494  http://schoolreports.cps.edu/SchoolProgressRep...
# 501  http://schoolreports.cps.edu/SchoolProgressRep...
# 518  http://schoolreports.cps.edu/SchoolProgressRep...
# 531  http://schoolreports.cps.edu/SchoolProgressRep...
# 532  http://schoolreports.cps.edu/SchoolProgressRep...
# 546  http://schoolreports.cps.edu/SchoolProgressRep...
# 553  http://schoolreports.cps.edu/SchoolProgressRep...
#
#                               Network Manager  ... Freshman on Track Rate %  \
# 0                Fullerton Elementary Network  ...                      NDA
# 10        Ravenswood-Ridge Elementary Network  ...                      NDA
# 27             Rock Island Elementary Network  ...                      NDA
# 39        Ravenswood-Ridge Elementary Network  ...                      NDA
# 118           Lake Calumet Elementary Network  ...                      NDA
# 119                 O'Hare Elementary Network  ...                      NDA
# 120                 O'Hare Elementary Network  ...                      NDA
# 141                 Fulton Elementary Network  ...                      NDA
# 213       Ravenswood-Ridge Elementary Network  ...                      NDA
# 244                 Skyway Elementary Network  ...                      NDA
# 245       Ravenswood-Ridge Elementary Network  ...                      NDA
# 286       Ravenswood-Ridge Elementary Network  ...                      NDA
# 326              Fullerton Elementary Network  ...                      NDA
# 366       Ravenswood-Ridge Elementary Network  ...                      NDA
# 408  North-Northwest Side High School Network  ...                     95.9
# 410  North-Northwest Side High School Network  ...                      NDA
# 412                 O'Hare Elementary Network  ...                      NDA
# 417                 O'Hare Elementary Network  ...                      NDA
# 446            South Side High School Network  ...                      NDA
# 474                 O'Hare Elementary Network  ...                      NDA
# 488       Ravenswood-Ridge Elementary Network  ...                      NDA
# 494                 Midway Elementary Network  ...                      NDA
# 501                 O'Hare Elementary Network  ...                      NDA
# 518  North-Northwest Side High School Network  ...                     90.7
# 531             West Side High School Network  ...                     96.7
# 532                 O'Hare Elementary Network  ...                      NDA
# 546              Fullerton Elementary Network  ...                      NDA
# 553            South Side High School Network  ...                     92.8
#
#     X_COORDINATE Y_COORDINATE   Latitude  Longitude COMMUNITY_AREA_NUMBER  \
# 0    1171699.458  1915829.428  41.924497 -87.644522                     7
# 10   1160327.881  1924862.722  41.949528 -87.686055                     5
# 27   1157959.455  1832892.067  41.697198 -87.697264                    74
# 39   1164768.164  1920682.831  41.937965 -87.669852                     6
# 118  1182742.505  1835063.900  41.702620 -87.606456                    50
# 119  1139595.896  1942911.685  41.999460 -87.761821                    12
# 120  1125476.537  1940915.071  41.994228 -87.813808                    10
# 141  1161269.097  1903925.361  41.892055 -87.683179                    24
# 213  1168069.526  1922284.759  41.942290 -87.657673                     6
# 244  1179172.217  1846656.745  41.734514 -87.619177                    44
# 245  1166063.167  1925373.268  41.950808 -87.664958                     6
# 286  1161693.811  1923258.727  41.945098 -87.681079                     5
# 326  1173614.170  1911976.635  41.913882 -87.637601                     7
# 366  1164156.393  1927985.538  41.958017 -87.671893                     6
# 408  1154090.859  1936413.866  41.981352 -87.708672                    13
# 410  1150357.037  1936987.496  41.983000 -87.722389                    13
# 412  1128430.406  1938729.626  41.988181 -87.802992                    10
# 417  1125978.285  1935191.982  41.978515 -87.812091                    10
# 446  1177161.058  1888615.131  41.849697 -87.625279                    33
# 474  1143919.392  1939921.031  41.991173 -87.745991                    12
# 488  1155108.239  1946608.822  42.009307 -87.704655                     2
# 494  1159597.930  1868206.829  41.794074 -87.690298                    63
# 501  1153858.196  1932691.891  41.971143 -87.709627                    14
# 518  1174484.638  1907490.082  41.901552 -87.634537                     8
# 531  1166475.742  1899058.627  41.878590 -87.664196                    28
# 532  1135078.471  1945800.949  42.007470 -87.778371                    12
# 546  1164875.342  1917368.608  41.928868 -87.669552                     7
# 553  1176412.354  1897618.088  41.874419 -87.627755                    32
#
#     COMMUNITY_AREA_NAME  Ward Police District                     Location
# 0          LINCOLN PARK    43              18  (41.92449696, -87.64452163)
# 10         NORTH CENTER    47              19  (41.94952795, -87.68605496)
# 27      MOUNT GREENWOOD    19              22   (41.69719792, -87.6972638)
# 39            LAKE VIEW    32              19  (41.93796493, -87.66985204)
# 118             PULLMAN     9               5  (41.70261965, -87.60645552)
# 119         FOREST GLEN    41              16   (41.99946016, -87.7618211)
# 120        NORWOOD PARK    41              16  (41.99422812, -87.81380814)
# 141           WEST TOWN    26              13  (41.89205482, -87.68317867)
# 213           LAKE VIEW    44              19  (41.94228994, -87.65767253)
# 244             CHATHAM     6               6  (41.73451387, -87.61917677)
# 245           LAKE VIEW    44              19  (41.95080812, -87.66495825)
# 286        NORTH CENTER    47              19  (41.94509808, -87.68107885)
# 326        LINCOLN PARK    43              18   (41.9138823, -87.63760107)
# 366           LAKE VIEW    47              19    (41.9580169, -87.6718933)
# 408          NORTH PARK    40              17  (41.98135196, -87.70867192)
# 410          NORTH PARK    39              17  (41.98299994, -87.72238881)
# 412        NORWOOD PARK    41              16  (41.98818136, -87.80299207)
# 417        NORWOOD PARK    41              16  (41.97851501, -87.81209057)
# 446     NEAR SOUTH SIDE     2               1   (41.84969736, -87.6252787)
# 474         FOREST GLEN    39              17  (41.99117332, -87.74599137)
# 488          WEST RIDGE    50              24  (42.00930696, -87.70465502)
# 494           GAGE PARK    14               9   (41.79407382, -87.6902983)
# 501         ALBANY PARK    39              17   (41.9711433, -87.70962725)
# 518     NEAR NORTH SIDE    27              18  (41.90155157, -87.63453744)
# 531      NEAR WEST SIDE     2              12  (41.87859028, -87.66419634)
# 532         FOREST GLEN    41              16  (42.00747007, -87.77837089)
# 546        LINCOLN PARK    32              19  (41.92886824, -87.66955245)
# 553                LOOP     2               1  (41.87441898, -87.62775497)
#
# [28 rows x 78 columns]

# %%
#Display all records but only columns School Id and Police Dsitrict  where Police district is not 19

df[df["Police District"]!=18 ][['School ID', 'Police District']]
# Out:
#      School ID  Police District
# 1       610281                4
# 2       610185                8
# 3       609993                9
# 4       610513                9
# 5       610212               17
# ..         ...              ...
# 561     610172                9
# 562     609844                2
# 563     610088               25
# 564     609977                3
# 565     610392               10
#
# [554 rows x 2 columns]

# %%
#Display  all records where community area is between 10-50
df[df["COMMUNITY_AREA_NUMBER"].between(10,50)]
# Out:
#      School ID                                     NAME_OF_SCHOOL  \
# 1       610281  Adam Clayton Powell Paideia Community Academy ...
# 4       610513                      Air Force Academy High School
# 5       610212                  Albany Park Multicultural Academy
# 7       610342            Albert R Sabin Elementary Magnet School
# 9       610209                 Alessandro Volta Elementary School
# ..         ...                                                ...
# 560     610336         Williams Preparatory Academy Middle School
# 562     609844                 William W Carter Elementary School
# 563     610088                Wolfgang A Mozart Elementary School
# 564     609977               Woodlawn Community Elementary School
# 565     610392                 World Language Academy High School
#
#     Elementary, Middle, or High School          Street Address     City State  \
# 1                                   ES  7511 S South Shore Dr   Chicago    IL
# 4                                   HS        3630 S Wells St   Chicago    IL
# 5                                   MS      4929 N Sawyer Ave   Chicago    IL
# 7                                   ES       2216 W Hirsch St   Chicago    IL
# 9                                   ES       4950 N Avers Ave   Chicago    IL
# ..                                 ...                     ...      ...   ...
# 560                                 MS     2710 S Dearborn St   Chicago    IL
# 562                                 ES    5740 S Michigan Ave   Chicago    IL
# 563                                 ES      2200 N Hamlin Ave   Chicago    IL
# 564                                 ES     6657 S Kimbark Ave   Chicago    IL
# 565                                 HS     3120 S Kostner Ave   Chicago    IL
#
#      ZIP Code    Phone Number  \
# 1       60649  (773) 535-6650
# 4       60609  (773) 535-1590
# 5       60625  (773) 534-5108
# 7       60622  (773) 534-4491
# 9       60625  (773) 534-5080
# ..        ...             ...
# 560     60616  (773) 534-9235
# 562     60637  (773) 535-0860
# 563     60647  (773) 534-4160
# 564     60637  (773) 535-0801
# 565     60623  (773) 535-4334
#
#                                                  Link   \
# 1    http://schoolreports.cps.edu/SchoolProgressRep...
# 4    http://schoolreports.cps.edu/SchoolProgressRep...
# 5    http://schoolreports.cps.edu/SchoolProgressRep...
# 7    http://schoolreports.cps.edu/SchoolProgressRep...
# 9    http://schoolreports.cps.edu/SchoolProgressRep...
# ..                                                 ...
# 560  http://schoolreports.cps.edu/SchoolProgressRep...
# 562  http://schoolreports.cps.edu/SchoolProgressRep...
# 563  http://schoolreports.cps.edu/SchoolProgressRep...
# 564  http://schoolreports.cps.edu/SchoolProgressRep...
# 565  http://schoolreports.cps.edu/SchoolProgressRep...
#
#                         Network Manager  ... Freshman on Track Rate %  \
# 1             Skyway Elementary Network  ...                      NDA
# 4    Southwest Side High School Network  ...                     91.8
# 5             O'Hare Elementary Network  ...                      NDA
# 7             Fulton Elementary Network  ...                      NDA
# 9             O'Hare Elementary Network  ...                      NDA
# ..                                  ...  ...                      ...
# 560     Burnham Park Elementary Network  ...                      NDA
# 562     Burnham Park Elementary Network  ...                      NDA
# 563        Fullerton Elementary Network  ...                      NDA
# 564     Burnham Park Elementary Network  ...                      NDA
# 565       West Side High School Network  ...                       76
#
#     X_COORDINATE Y_COORDINATE   Latitude  Longitude COMMUNITY_AREA_NUMBER  \
# 1    1196129.985  1856209.466  41.760324 -87.556736                    43
# 4    1175177.622  1880745.126  41.828146 -87.632794                    34
# 5    1153858.196  1932691.891  41.971143 -87.709627                    14
# 7    1161265.299  1909314.592  41.906843 -87.683043                    24
# 9    1149774.095  1932831.151  41.971606 -87.724641                    14
# ..           ...          ...        ...        ...                   ...
# 560  1176275.784  1886545.486  41.844038 -87.628590                    35
# 562  1178101.365  1866810.123  41.789841 -87.622490                    40
# 563  1150644.396  1914368.955  41.920927 -87.721925                    22
# 564  1185825.188  1860883.579  41.773400 -87.594356                    42
# 565  1147521.302  1883405.128  41.836020 -87.734195                    30
#
#     COMMUNITY_AREA_NAME  Ward Police District                     Location
# 1           SOUTH SHORE     7               4  (41.76032435, -87.55673627)
# 4         ARMOUR SQUARE    11               9  (41.82814609, -87.63279369)
# 5           ALBANY PARK    39              17   (41.9711433, -87.70962725)
# 7             WEST TOWN     1              14  (41.90684338, -87.68304259)
# 9           ALBANY PARK    39              17  (41.97160605, -87.72464139)
# ..                  ...   ...             ...                          ...
# 560             DOUGLAS     3               1  (41.84403809, -87.62859008)
# 562     WASHINGTON PARK    20               2  (41.78984129, -87.62248974)
# 563        LOGAN SQUARE    35              25  (41.92092734, -87.72192541)
# 564            WOODLAWN     5               3  (41.77339962, -87.59435584)
# 565      SOUTH LAWNDALE    22              10  (41.83601953, -87.73419465)
#
# [328 rows x 78 columns]

# %%
# To display all rows with index labels greater than 1, we will give the following command:
m=df.index>1
# df[m]
df[df.index>1]
# Out:
#      School ID                        NAME_OF_SCHOOL  \
# 2       610185   Adlai E Stevenson Elementary School
# 3       609993       Agustin Lara Elementary Academy
# 4       610513         Air Force Academy High School
# 5       610212     Albany Park Multicultural Academy
# 6       609720   Albert G Lane Technical High School
# ..         ...                                   ...
# 561     610172   William T Sherman Elementary School
# 562     609844    William W Carter Elementary School
# 563     610088   Wolfgang A Mozart Elementary School
# 564     609977  Woodlawn Community Elementary School
# 565     610392    World Language Academy High School
#
#     Elementary, Middle, or High School        Street Address     City State  \
# 2                                   ES   8010 S Kostner Ave   Chicago    IL
# 3                                   ES   4619 S Wolcott Ave   Chicago    IL
# 4                                   HS      3630 S Wells St   Chicago    IL
# 5                                   MS    4929 N Sawyer Ave   Chicago    IL
# 6                                   HS    2501 W Addison St   Chicago    IL
# ..                                 ...                   ...      ...   ...
# 561                                 ES       1000 W 52nd St   Chicago    IL
# 562                                 ES  5740 S Michigan Ave   Chicago    IL
# 563                                 ES    2200 N Hamlin Ave   Chicago    IL
# 564                                 ES   6657 S Kimbark Ave   Chicago    IL
# 565                                 HS   3120 S Kostner Ave   Chicago    IL
#
#      ZIP Code    Phone Number  \
# 2       60652  (773) 535-2280
# 3       60609  (773) 535-4389
# 4       60609  (773) 535-1590
# 5       60625  (773) 534-5108
# 6       60618  (773) 534-5400
# ..        ...             ...
# 561     60609  (773) 535-1757
# 562     60637  (773) 535-0860
# 563     60647  (773) 534-4160
# 564     60637  (773) 535-0801
# 565     60623  (773) 535-4334
#
#                                                  Link   \
# 2    http://schoolreports.cps.edu/SchoolProgressRep...
# 3    http://schoolreports.cps.edu/SchoolProgressRep...
# 4    http://schoolreports.cps.edu/SchoolProgressRep...
# 5    http://schoolreports.cps.edu/SchoolProgressRep...
# 6    http://schoolreports.cps.edu/SchoolProgressRep...
# ..                                                 ...
# 561  http://schoolreports.cps.edu/SchoolProgressRep...
# 562  http://schoolreports.cps.edu/SchoolProgressRep...
# 563  http://schoolreports.cps.edu/SchoolProgressRep...
# 564  http://schoolreports.cps.edu/SchoolProgressRep...
# 565  http://schoolreports.cps.edu/SchoolProgressRep...
#
#                               Network Manager  ... Freshman on Track Rate %  \
# 2                   Midway Elementary Network  ...                      NDA
# 3                 Pershing Elementary Network  ...                      NDA
# 4          Southwest Side High School Network  ...                     91.8
# 5                   O'Hare Elementary Network  ...                      NDA
# 6    North-Northwest Side High School Network  ...                     90.7
# ..                                        ...  ...                      ...
# 561                              AUSL Schools  ...                      NDA
# 562           Burnham Park Elementary Network  ...                      NDA
# 563              Fullerton Elementary Network  ...                      NDA
# 564           Burnham Park Elementary Network  ...                      NDA
# 565             West Side High School Network  ...                       76
#
#     X_COORDINATE Y_COORDINATE   Latitude  Longitude COMMUNITY_AREA_NUMBER  \
# 2    1148427.165  1851012.215  41.747111 -87.731702                    70
# 3    1164504.290  1873959.199  41.809757 -87.672145                    61
# 4    1175177.622  1880745.126  41.828146 -87.632794                    34
# 5    1153858.196  1932691.891  41.971143 -87.709627                    14
# 6    1158975.392  1923791.705  41.946617 -87.691056                     5
# ..           ...          ...        ...        ...                   ...
# 561  1170500.817  1870373.159  41.799788 -87.650255                    61
# 562  1178101.365  1866810.123  41.789841 -87.622490                    40
# 563  1150644.396  1914368.955  41.920927 -87.721925                    22
# 564  1185825.188  1860883.579  41.773400 -87.594356                    42
# 565  1147521.302  1883405.128  41.836020 -87.734195                    30
#
#     COMMUNITY_AREA_NAME  Ward Police District                     Location
# 2               ASHBURN    13               8  (41.74711093, -87.73170248)
# 3              NEW CITY    20               9    (41.8097569, -87.6721446)
# 4         ARMOUR SQUARE    11               9  (41.82814609, -87.63279369)
# 5           ALBANY PARK    39              17   (41.9711433, -87.70962725)
# 6          NORTH CENTER    47              19  (41.94661693, -87.69105603)
# ..                  ...   ...             ...                          ...
# 561            NEW CITY    16               9  (41.79978772, -87.65025483)
# 562     WASHINGTON PARK    20               2  (41.78984129, -87.62248974)
# 563        LOGAN SQUARE    35              25  (41.92092734, -87.72192541)
# 564            WOODLAWN     5               3  (41.77339962, -87.59435584)
# 565      SOUTH LAWNDALE    22              10  (41.83601953, -87.73419465)
#
# [564 rows x 78 columns]

# %% [markdown]
# **PLOTTING USING DATAFRAME**

# %%
data=df.head(20)

# %%
data.plot(x='COMMUNITY_AREA_NAME', y='SAFETY_SCORE', kind='scatter')
# Out:
# <Axes: xlabel='COMMUNITY_AREA_NAME', ylabel='SAFETY_SCORE'>

# %%
data.plot(x='COMMUNITY_AREA_NAME', y='SAFETY_SCORE', kind='line')
# Out:
# <Axes: xlabel='COMMUNITY_AREA_NAME'>

# %%
data.plot(x='COMMUNITY_AREA_NAME', y='SAFETY_SCORE', kind='bar')
# Out:
# <Axes: xlabel='COMMUNITY_AREA_NAME'>

# %%
data.plot( y='SAFETY_SCORE', kind='pie')
# Out:
# <Axes: ylabel='SAFETY_SCORE'>

# %%
data.plot.pie(y='SAFETY_SCORE', figsize=(5, 5), autopct='%1.1f%%', startangle=90)
# Out:
# <Axes: ylabel='SAFETY_SCORE'>
